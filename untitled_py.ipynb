# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarfaraz4054/01_AI_Virtual_Mouse/blob/master/untitled_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world
